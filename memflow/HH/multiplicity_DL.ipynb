# %%
# %load_ext autoreload
# %autoreload 2

import time
import math
import copy
import torch
from torch import nn, optim
import numpy as np
import awkward as ak
import uproot
import pandas as pd
import dask
import vector
import particle
import hepunits

import zuko
import torch
from torch import nn, optim
import lightning as L
from lightning.pytorch import loggers as pl_loggers

from torch.utils.data import DataLoader

from memflow.dataset.data import RootData,ParquetData
from memflow.dataset.dataset import MultiplicityDataset
from memflow.HH.HH import HHbbWWDoubleLeptonGenDataset,HHbbWWDoubleLeptonRecoDataset
from memflow.read_data import utils
from memflow.models.classifier import MultiClassifier

from memflow.callbacks.classifier_callbacks import *

from matplotlib import pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 100})

vector.register_awkward()

print (f"Running on GPU : {torch.cuda.is_available()}")
accelerator = 'gpu' if torch.cuda.is_available() else 'cpu'
print (f"Accelerator : {accelerator}")
torch.set_float32_matmul_precision('medium')  
if accelerator =='gpu':
    torch.cuda.empty_cache()
    print (torch.cuda.memory_summary(device=None, abbreviated=True))
# Out:
# Running on GPU : True
# Accelerator : gpu
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Active memory         |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Requested memory      |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
gen_data = RootData(
    files = [
        '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH0.root',
        '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH1.root',
        '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH2p45.root',
        '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH5.root',
    ],
    treenames = [
        'gen_HH;1',
    ],
    lazy = True,
    #N = 10000,
)

print (gen_data)
# Out:
# Data object
# Loaded branches:
#    ... file: 1589994
#    ... sample: 1589994
#    ... tree: 1589994
# Branch in files not loaded:
#    ... H1_E
#    ... H1_Px
#    ... H1_Py
#    ... H1_Pz
#    ... H1_eta
#    ... H1_idx
#    ... H1_mass
#    ... H1_pdgId
#    ... H1_phi
#    ... H1_pt
#    ... H1_sum_E
#    ... H2_E
#    ... H2_Px
#    ... H2_Py
#    ... H2_Pz
#    ... H2_eta
#    ... H2_idx
#    ... H2_mass
#    ... H2_pdgId
#    ... H2_phi
#    ... H2_pt
#    ... H2_sum_E
#    ... ISR_10_E
#    ... ISR_10_Px
#    ... ISR_10_Py
#    ... ISR_10_Pz
#    ... ISR_10_eta
#    ... ISR_10_idx
#    ... ISR_10_mass
#    ... ISR_10_parent
#    ... ISR_10_pdgId
#    ... ISR_10_phi
#    ... ISR_10_pt
#    ... ISR_11_E
#    ... ISR_11_Px
#    ... ISR_11_Py
#    ... ISR_11_Pz
#    ... ISR_11_eta
#    ... ISR_11_idx
#    ... ISR_11_mass
#    ... ISR_11_parent
#    ... ISR_11_pdgId
#    ... ISR_11_phi
#    ... ISR_11_pt
#    ... ISR_12_E
#    ... ISR_12_Px
#    ... ISR_12_Py
#    ... ISR_12_Pz
#    ... ISR_12_eta
#    ... ISR_12_idx
#    ... ISR_12_mass
#    ... ISR_12_parent
#    ... ISR_12_pdgId
#    ... ISR_12_phi
#    ... ISR_12_pt
#    ... ISR_13_E
#    ... ISR_13_Px
#    ... ISR_13_Py
#    ... ISR_13_Pz
#    ... ISR_13_eta
#    ... ISR_13_idx
#    ... ISR_13_mass
#    ... ISR_13_parent
#    ... ISR_13_pdgId
#    ... ISR_13_phi
#    ... ISR_13_pt
#    ... ISR_14_E
#    ... ISR_14_Px
#    ... ISR_14_Py
#    ... ISR_14_Pz
#    ... ISR_14_eta
#    ... ISR_14_idx
#    ... ISR_14_mass
#    ... ISR_14_parent
#    ... ISR_14_pdgId
#    ... ISR_14_phi
#    ... ISR_14_pt
#    ... ISR_15_E
#    ... ISR_15_Px
#    ... ISR_15_Py
#    ... ISR_15_Pz
#    ... ISR_15_eta
#    ... ISR_15_idx
#    ... ISR_15_mass
#    ... ISR_15_parent
#    ... ISR_15_pdgId
#    ... ISR_15_phi
#    ... ISR_15_pt
#    ... ISR_1_E
#    ... ISR_1_Px
#    ... ISR_1_Py
#    ... ISR_1_Pz
#    ... ISR_1_eta
#    ... ISR_1_idx
#    ... ISR_1_mass
#    ... ISR_1_parent
#    ... ISR_1_pdgId
#    ... ISR_1_phi
#    ... ISR_1_pt
#    ... ISR_2_E
#    ... ISR_2_Px
#    ... ISR_2_Py
#    ... ISR_2_Pz
#    ... ISR_2_eta
#    ... ISR_2_idx
#    ... ISR_2_mass
#    ... ISR_2_parent
#    ... ISR_2_pdgId
#    ... ISR_2_phi
#    ... ISR_2_pt
#    ... ISR_3_E
#    ... ISR_3_Px
#    ... ISR_3_Py
#    ... ISR_3_Pz
#    ... ISR_3_eta
#    ... ISR_3_idx
#    ... ISR_3_mass
#    ... ISR_3_parent
#    ... ISR_3_pdgId
#    ... ISR_3_phi
#    ... ISR_3_pt
#    ... ISR_4_E
#    ... ISR_4_Px
#    ... ISR_4_Py
#    ... ISR_4_Pz
#    ... ISR_4_eta
#    ... ISR_4_idx
#    ... ISR_4_mass
#    ... ISR_4_parent
#    ... ISR_4_pdgId
#    ... ISR_4_phi
#    ... ISR_4_pt
#    ... ISR_5_E
#    ... ISR_5_Px
#    ... ISR_5_Py
#    ... ISR_5_Pz
#    ... ISR_5_eta
#    ... ISR_5_idx
#    ... ISR_5_mass
#    ... ISR_5_parent
#    ... ISR_5_pdgId
#    ... ISR_5_phi
#    ... ISR_5_pt
#    ... ISR_6_E
#    ... ISR_6_Px
#    ... ISR_6_Py
#    ... ISR_6_Pz
#    ... ISR_6_eta
#    ... ISR_6_idx
#    ... ISR_6_mass
#    ... ISR_6_parent
#    ... ISR_6_pdgId
#    ... ISR_6_phi
#    ... ISR_6_pt
#    ... ISR_7_E
#    ... ISR_7_Px
#    ... ISR_7_Py
#    ... ISR_7_Pz
#    ... ISR_7_eta
#    ... ISR_7_idx
#    ... ISR_7_mass
#    ... ISR_7_parent
#    ... ISR_7_pdgId
#    ... ISR_7_phi
#    ... ISR_7_pt
#    ... ISR_8_E
#    ... ISR_8_Px
#    ... ISR_8_Py
#    ... ISR_8_Pz
#    ... ISR_8_eta
#    ... ISR_8_idx
#    ... ISR_8_mass
#    ... ISR_8_parent
#    ... ISR_8_pdgId
#    ... ISR_8_phi
#    ... ISR_8_pt
#    ... ISR_9_E
#    ... ISR_9_Px
#    ... ISR_9_Py
#    ... ISR_9_Pz
#    ... ISR_9_eta
#    ... ISR_9_idx
#    ... ISR_9_mass
#    ... ISR_9_parent
#    ... ISR_9_pdgId
#    ... ISR_9_phi
#    ... ISR_9_pt
#    ... W_minus_E
#    ... W_minus_Px
#    ... W_minus_Py
#    ... W_minus_Pz
#    ... W_minus_eta
#    ... W_minus_idx
#    ... W_minus_mass
#    ... W_minus_pdgId
#    ... W_minus_phi
#    ... W_minus_pt
#    ... W_minus_sum_E
#    ... W_plus_E
#    ... W_plus_Px
#    ... W_plus_Py
#    ... W_plus_Pz
#    ... W_plus_eta
#    ... W_plus_idx
#    ... W_plus_mass
#    ... W_plus_pdgId
#    ... W_plus_phi
#    ... W_plus_pt
#    ... W_plus_sum_E
#    ... Z1_E
#    ... Z1_Px
#    ... Z1_Py
#    ... Z1_Pz
#    ... Z1_eta
#    ... Z1_idx
#    ... Z1_mass
#    ... Z1_pdgId
#    ... Z1_phi
#    ... Z1_pt
#    ... Z1_sum_E
#    ... Z2_E
#    ... Z2_Px
#    ... Z2_Py
#    ... Z2_Pz
#    ... Z2_eta
#    ... Z2_idx
#    ... Z2_mass
#    ... Z2_pdgId
#    ... Z2_phi
#    ... Z2_pt
#    ... Z2_sum_E
#    ... antibottom_E
#    ... antibottom_Px
#    ... antibottom_Py
#    ... antibottom_Pz
#    ... antibottom_eta
#    ... antibottom_idx
#    ... antibottom_mass
#    ... antibottom_pdgId
#    ... antibottom_phi
#    ... antibottom_pt
#    ... antibottom_sum_E
#    ... antineutrino_from_W_E
#    ... antineutrino_from_W_Px
#    ... antineutrino_from_W_Py
#    ... antineutrino_from_W_Pz
#    ... antineutrino_from_W_eta
#    ... antineutrino_from_W_idx
#    ... antineutrino_from_W_mass
#    ... antineutrino_from_W_pdgId
#    ... antineutrino_from_W_phi
#    ... antineutrino_from_W_pt
#    ... antineutrino_from_W_sum_E
#    ... antineutrino_from_Z_E
#    ... antineutrino_from_Z_Px
#    ... antineutrino_from_Z_Py
#    ... antineutrino_from_Z_Pz
#    ... antineutrino_from_Z_eta
#    ... antineutrino_from_Z_idx
#    ... antineutrino_from_Z_mass
#    ... antineutrino_from_Z_pdgId
#    ... antineutrino_from_Z_phi
#    ... antineutrino_from_Z_pt
#    ... antineutrino_from_Z_sum_E
#    ... antiquark_down_from_W_E
#    ... antiquark_down_from_W_Px
#    ... antiquark_down_from_W_Py
#    ... antiquark_down_from_W_Pz
#    ... antiquark_down_from_W_eta
#    ... antiquark_down_from_W_idx
#    ... antiquark_down_from_W_mass
#    ... antiquark_down_from_W_pdgId
#    ... antiquark_down_from_W_phi
#    ... antiquark_down_from_W_pt
#    ... antiquark_down_from_W_sum_E
#    ... antiquark_down_from_Z_E
#    ... antiquark_down_from_Z_Px
#    ... antiquark_down_from_Z_Py
#    ... antiquark_down_from_Z_Pz
#    ... antiquark_down_from_Z_eta
#    ... antiquark_down_from_Z_idx
#    ... antiquark_down_from_Z_mass
#    ... antiquark_down_from_Z_pdgId
#    ... antiquark_down_from_Z_phi
#    ... antiquark_down_from_Z_pt
#    ... antiquark_down_from_Z_sum_E
#    ... antiquark_up_from_W_E
#    ... antiquark_up_from_W_Px
#    ... antiquark_up_from_W_Py
#    ... antiquark_up_from_W_Pz
#    ... antiquark_up_from_W_eta
#    ... antiquark_up_from_W_idx
#    ... antiquark_up_from_W_mass
#    ... antiquark_up_from_W_pdgId
#    ... antiquark_up_from_W_phi
#    ... antiquark_up_from_W_pt
#    ... antiquark_up_from_W_sum_E
#    ... antiquark_up_from_Z_E
#    ... antiquark_up_from_Z_Px
#    ... antiquark_up_from_Z_Py
#    ... antiquark_up_from_Z_Pz
#    ... antiquark_up_from_Z_eta
#    ... antiquark_up_from_Z_idx
#    ... antiquark_up_from_Z_mass
#    ... antiquark_up_from_Z_pdgId
#    ... antiquark_up_from_Z_phi
#    ... antiquark_up_from_Z_pt
#    ... antiquark_up_from_Z_sum_E
#    ... bottom_E
#    ... bottom_Px
#    ... bottom_Py
#    ... bottom_Pz
#    ... bottom_eta
#    ... bottom_idx
#    ... bottom_mass
#    ... bottom_pdgId
#    ... bottom_phi
#    ... bottom_pt
#    ... bottom_sum_E
#    ... event
#    ... flag_valid
#    ... lep_minus_from_W_E
#    ... lep_minus_from_W_Px
#    ... lep_minus_from_W_Py
#    ... lep_minus_from_W_Pz
#    ... lep_minus_from_W_eta
#    ... lep_minus_from_W_idx
#    ... lep_minus_from_W_mass
#    ... lep_minus_from_W_pdgId
#    ... lep_minus_from_W_phi
#    ... lep_minus_from_W_pt
#    ... lep_minus_from_W_sum_E
#    ... lep_minus_from_Z_E
#    ... lep_minus_from_Z_Px
#    ... lep_minus_from_Z_Py
#    ... lep_minus_from_Z_Pz
#    ... lep_minus_from_Z_eta
#    ... lep_minus_from_Z_idx
#    ... lep_minus_from_Z_mass
#    ... lep_minus_from_Z_pdgId
#    ... lep_minus_from_Z_phi
#    ... lep_minus_from_Z_pt
#    ... lep_minus_from_Z_sum_E
#    ... lep_plus_from_W_E
#    ... lep_plus_from_W_Px
#    ... lep_plus_from_W_Py
#    ... lep_plus_from_W_Pz
#    ... lep_plus_from_W_eta
#    ... lep_plus_from_W_idx
#    ... lep_plus_from_W_mass
#    ... lep_plus_from_W_pdgId
#    ... lep_plus_from_W_phi
#    ... lep_plus_from_W_pt
#    ... lep_plus_from_W_sum_E
#    ... lep_plus_from_Z_E
#    ... lep_plus_from_Z_Px
#    ... lep_plus_from_Z_Py
#    ... lep_plus_from_Z_Pz
#    ... lep_plus_from_Z_eta
#    ... lep_plus_from_Z_idx
#    ... lep_plus_from_Z_mass
#    ... lep_plus_from_Z_pdgId
#    ... lep_plus_from_Z_phi
#    ... lep_plus_from_Z_pt
#    ... lep_plus_from_Z_sum_E
#    ... n_ISR
#    ... n_W_minus
#    ... n_W_plus
#    ... n_antibottom
#    ... n_antineutrino_from_W
#    ... n_antineutrino_from_Z
#    ... n_antiquark_down_from_W
#    ... n_antiquark_down_from_Z
#    ... n_antiquark_up_from_W
#    ... n_antiquark_up_from_Z
#    ... n_bottom
#    ... n_lep_minus_from_W
#    ... n_lep_minus_from_Z
#    ... n_lep_plus_from_W
#    ... n_lep_plus_from_Z
#    ... n_neutrino_from_W
#    ... n_neutrino_from_Z
#    ... n_quark_down_from_W
#    ... n_quark_down_from_Z
#    ... n_quark_up_from_W
#    ... n_quark_up_from_Z
#    ... neutrino_from_W_E
#    ... neutrino_from_W_Px
#    ... neutrino_from_W_Py
#    ... neutrino_from_W_Pz
#    ... neutrino_from_W_eta
#    ... neutrino_from_W_idx
#    ... neutrino_from_W_mass
#    ... neutrino_from_W_pdgId
#    ... neutrino_from_W_phi
#    ... neutrino_from_W_pt
#    ... neutrino_from_W_sum_E
#    ... neutrino_from_Z_E
#    ... neutrino_from_Z_Px
#    ... neutrino_from_Z_Py
#    ... neutrino_from_Z_Pz
#    ... neutrino_from_Z_eta
#    ... neutrino_from_Z_idx
#    ... neutrino_from_Z_mass
#    ... neutrino_from_Z_pdgId
#    ... neutrino_from_Z_phi
#    ... neutrino_from_Z_pt
#    ... neutrino_from_Z_sum_E
#    ... quark_down_from_W_E
#    ... quark_down_from_W_Px
#    ... quark_down_from_W_Py
#    ... quark_down_from_W_Pz
#    ... quark_down_from_W_eta
#    ... quark_down_from_W_idx
#    ... quark_down_from_W_mass
#    ... quark_down_from_W_pdgId
#    ... quark_down_from_W_phi
#    ... quark_down_from_W_pt
#    ... quark_down_from_W_sum_E
#    ... quark_down_from_Z_E
#    ... quark_down_from_Z_Px
#    ... quark_down_from_Z_Py
#    ... quark_down_from_Z_Pz
#    ... quark_down_from_Z_eta
#    ... quark_down_from_Z_idx
#    ... quark_down_from_Z_mass
#    ... quark_down_from_Z_pdgId
#    ... quark_down_from_Z_phi
#    ... quark_down_from_Z_pt
#    ... quark_down_from_Z_sum_E
#    ... quark_up_from_W_E
#    ... quark_up_from_W_Px
#    ... quark_up_from_W_Py
#    ... quark_up_from_W_Pz
#    ... quark_up_from_W_eta
#    ... quark_up_from_W_idx
#    ... quark_up_from_W_mass
#    ... quark_up_from_W_pdgId
#    ... quark_up_from_W_phi
#    ... quark_up_from_W_pt
#    ... quark_up_from_W_sum_E
#    ... quark_up_from_Z_E
#    ... quark_up_from_Z_Px
#    ... quark_up_from_Z_Py
#    ... quark_up_from_Z_Pz
#    ... quark_up_from_Z_eta
#    ... quark_up_from_Z_idx
#    ... quark_up_from_Z_mass
#    ... quark_up_from_Z_pdgId
#    ... quark_up_from_Z_phi
#    ... quark_up_from_Z_pt
#    ... quark_up_from_Z_sum_E

# %%
gen_dataset = HHbbWWDoubleLeptonGenDataset(
    data = gen_data,
    selection = [
        'leptons',
        'bquarks',
    ],
    coordinates = 'cylindrical',
    default_features = {
        'pt': 0.,
        'eta': 0.,
        'phi': 0.,
        'mass': 0.,
        'pdgId' : None,
    },
    apply_boost = False,
    apply_preprocessing = True,
    build = True,
    dtype = torch.float32,
)
print (gen_dataset)

print ('Before preprocessing')
gen_dataset.plot(selection=True,raw=True)
print ('After preprocessing')
gen_dataset.plot(selection=True,raw=False)
# Out:
# Selecting 1519507 events out of 1589994
# Saving objects to /auto/home/users/f/b/fbury/HHMEM/MEMFlow/memflow/HH/hh_gen
# No final state recorded with `final_states_object_name` property, will not compute PS points
# Parton dataset with 1519507 events
#  Initial states pdgids : [21, 21]
#  Final states pdgids   : [6, -6, 11, -12, -11, 12]
#  Final states masses   : [172.5, 172.5, 0.0005109989499999999, 0.0, 0.0005109989499999999, 0.0]
# Containing the following tensors
# leptons  : data ([1519507, 4, 4]), mask ([1519507, 4])
#            Mask exist    : [100.00%, 100.00%, 100.00%, 100.00%]
#            Mask corr     : [True, True, True, True]
#            Weights       : 1519507.00, 1519507.00, 1519507.00, 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass']
#            Selected for batches : True
# higgs    : data ([1519507, 2, 4]), mask ([1519507, 2])
#            Mask exist    : [100.00%, 100.00%]
#            Mask corr     : [True, True]
#            Weights       : 1519507.00, 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass']
#            Selected for batches : False
# bquarks  : data ([1519507, 2, 4]), mask ([1519507, 2])
#            Mask exist    : [100.00%, 100.00%]
#            Mask corr     : [True, True]
#            Weights       : 1519507.00, 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass']
#            Selected for batches : True
# boost    : data ([1519507, 1, 4]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass']
#            Selected for batches : False
# b        : data ([1519507, 1, 8]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass', 'E', 'px', 'py', 'pz']
#            Selected for batches : False
# bbar     : data ([1519507, 1, 8]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass', 'E', 'px', 'py', 'pz']
#            Selected for batches : False
# l+       : data ([1519507, 1, 8]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass', 'E', 'px', 'py', 'pz']
#            Selected for batches : False
# v        : data ([1519507, 1, 8]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass', 'E', 'px', 'py', 'pz']
#            Selected for batches : False
# l-       : data ([1519507, 1, 8]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass', 'E', 'px', 'py', 'pz']
#            Selected for batches : False
# vbar     : data ([1519507, 1, 8]), mask ([1519507, 1])
#            Mask exist    : [100.00%]
#            Mask corr     : [True]
#            Weights       : 1519507.00
#            Features      : ['pt', 'eta', 'phi', 'mass', 'E', 'px', 'py', 'pz']
#            Selected for batches : False
# Preprocessing steps
# Step applied to ['leptons', 'higgs', 'bquarks']
# 	pt  : <class 'memflow.dataset.preprocessing.logmodulus'>
#   - leptons : ('pt',)
#   - higgs   : ('pt',)
#   - bquarks : ('pt',)
# Step applied to ['leptons', 'higgs', 'bquarks']
# 	pt   : <class 'memflow.dataset.preprocessing.SklearnScaler'>
# 	eta  : <class 'memflow.dataset.preprocessing.SklearnScaler'>
# 	phi  : <class 'memflow.dataset.preprocessing.SklearnScaler'>
# 	m    : <class 'memflow.dataset.preprocessing.SklearnScaler'>
#   - leptons : ('pt', 'eta', 'phi', 'm')
#   - higgs   : ('pt', 'eta', 'phi', 'm')
#   - bquarks : ('pt', 'eta', 'phi', 'm')
#
# Before preprocessing
# After preprocessing

# %%
reco_data = RootData(
    files = gen_data.files,
    treenames = [
        'reco_DL;1',
    ],
    lazy = True,
    N = gen_data.N,
)
print ('Initial :',reco_data.events)

mask_resolved = np.logical_and.reduce(
    (
        reco_data['flag_SR']==1, 
        reco_data['flag_resolved']==1,
        reco_data['n_AK4']<= 8,
    )
)
reco_data.cut(mask_resolved)
print ('Resolved SR :',reco_data.events)
print (reco_data)
# Out:
# Initial : 1589994
# Resolved SR : 221454
# Data object
# Loaded branches:
#    ... file: 221454
#    ... flag_SR: 221454
#    ... flag_resolved: 221454
#    ... n_AK4: 221454
#    ... sample: 221454
#    ... tree: 221454
# Branch in files not loaded:
#    ... VBF1_E
#    ... VBF1_Px
#    ... VBF1_Py
#    ... VBF1_Pz
#    ... VBF1_eta
#    ... VBF1_idx
#    ... VBF1_mass
#    ... VBF1_phi
#    ... VBF1_pt
#    ... VBF1_sel
#    ... VBF2_E
#    ... VBF2_Px
#    ... VBF2_Py
#    ... VBF2_Pz
#    ... VBF2_eta
#    ... VBF2_idx
#    ... VBF2_mass
#    ... VBF2_phi
#    ... VBF2_pt
#    ... VBF2_sel
#    ... VBF3_E
#    ... VBF3_Px
#    ... VBF3_Py
#    ... VBF3_Pz
#    ... VBF3_eta
#    ... VBF3_idx
#    ... VBF3_mass
#    ... VBF3_phi
#    ... VBF3_pt
#    ... VBF3_sel
#    ... VBF4_E
#    ... VBF4_Px
#    ... VBF4_Py
#    ... VBF4_Pz
#    ... VBF4_eta
#    ... VBF4_idx
#    ... VBF4_mass
#    ... VBF4_phi
#    ... VBF4_pt
#    ... VBF4_sel
#    ... VBF5_E
#    ... VBF5_Px
#    ... VBF5_Py
#    ... VBF5_Pz
#    ... VBF5_eta
#    ... VBF5_idx
#    ... VBF5_mass
#    ... VBF5_phi
#    ... VBF5_pt
#    ... VBF5_sel
#    ... VBF6_E
#    ... VBF6_Px
#    ... VBF6_Py
#    ... VBF6_Pz
#    ... VBF6_eta
#    ... VBF6_idx
#    ... VBF6_mass
#    ... VBF6_phi
#    ... VBF6_pt
#    ... VBF6_sel
#    ... VBF7_E
#    ... VBF7_Px
#    ... VBF7_Py
#    ... VBF7_Pz
#    ... VBF7_eta
#    ... VBF7_idx
#    ... VBF7_mass
#    ... VBF7_phi
#    ... VBF7_pt
#    ... VBF7_sel
#    ... VBF8_E
#    ... VBF8_Px
#    ... VBF8_Py
#    ... VBF8_Pz
#    ... VBF8_eta
#    ... VBF8_idx
#    ... VBF8_mass
#    ... VBF8_phi
#    ... VBF8_pt
#    ... VBF8_sel
#    ... e1_E
#    ... e1_Px
#    ... e1_Py
#    ... e1_Pz
#    ... e1_charge
#    ... e1_eta
#    ... e1_idx
#    ... e1_mass
#    ... e1_pdgId
#    ... e1_phi
#    ... e1_pt
#    ... e2_E
#    ... e2_Px
#    ... e2_Py
#    ... e2_Pz
#    ... e2_charge
#    ... e2_eta
#    ... e2_idx
#    ... e2_mass
#    ... e2_pdgId
#    ... e2_phi
#    ... e2_pt
#    ... e3_E
#    ... e3_Px
#    ... e3_Py
#    ... e3_Pz
#    ... e3_charge
#    ... e3_eta
#    ... e3_idx
#    ... e3_mass
#    ... e3_pdgId
#    ... e3_phi
#    ... e3_pt
#    ... e4_E
#    ... e4_Px
#    ... e4_Py
#    ... e4_Pz
#    ... e4_charge
#    ... e4_eta
#    ... e4_idx
#    ... e4_mass
#    ... e4_pdgId
#    ... e4_phi
#    ... e4_pt
#    ... event
#    ... fatj_E
#    ... fatj_Px
#    ... fatj_Py
#    ... fatj_Pz
#    ... fatj_eta
#    ... fatj_idx
#    ... fatj_mass
#    ... fatj_phi
#    ... fatj_pt
#    ... fatj_sub1_E
#    ... fatj_sub1_Px
#    ... fatj_sub1_Py
#    ... fatj_sub1_Pz
#    ... fatj_sub1_btag
#    ... fatj_sub1_btagged
#    ... fatj_sub1_eta
#    ... fatj_sub1_idx
#    ... fatj_sub1_mass
#    ... fatj_sub1_phi
#    ... fatj_sub1_pt
#    ... fatj_sub2_E
#    ... fatj_sub2_Px
#    ... fatj_sub2_Py
#    ... fatj_sub2_Pz
#    ... fatj_sub2_btag
#    ... fatj_sub2_btagged
#    ... fatj_sub2_eta
#    ... fatj_sub2_idx
#    ... fatj_sub2_mass
#    ... fatj_sub2_phi
#    ... fatj_sub2_pt
#    ... flag_ElEl
#    ... flag_ElMu
#    ... flag_MuMu
#    ... flag_boosted
#    ... j10_E
#    ... j10_Px
#    ... j10_Py
#    ... j10_Pz
#    ... j10_btag
#    ... j10_btagged
#    ... j10_eta
#    ... j10_idx
#    ... j10_mass
#    ... j10_phi
#    ... j10_pt
#    ... j11_E
#    ... j11_Px
#    ... j11_Py
#    ... j11_Pz
#    ... j11_btag
#    ... j11_btagged
#    ... j11_eta
#    ... j11_idx
#    ... j11_mass
#    ... j11_phi
#    ... j11_pt
#    ... j12_E
#    ... j12_Px
#    ... j12_Py
#    ... j12_Pz
#    ... j12_btag
#    ... j12_btagged
#    ... j12_eta
#    ... j12_idx
#    ... j12_mass
#    ... j12_phi
#    ... j12_pt
#    ... j13_E
#    ... j13_Px
#    ... j13_Py
#    ... j13_Pz
#    ... j13_btag
#    ... j13_btagged
#    ... j13_eta
#    ... j13_idx
#    ... j13_mass
#    ... j13_phi
#    ... j13_pt
#    ... j14_E
#    ... j14_Px
#    ... j14_Py
#    ... j14_Pz
#    ... j14_btag
#    ... j14_btagged
#    ... j14_eta
#    ... j14_idx
#    ... j14_mass
#    ... j14_phi
#    ... j14_pt
#    ... j15_E
#    ... j15_Px
#    ... j15_Py
#    ... j15_Pz
#    ... j15_btag
#    ... j15_btagged
#    ... j15_eta
#    ... j15_idx
#    ... j15_mass
#    ... j15_phi
#    ... j15_pt
#    ... j1_E
#    ... j1_Px
#    ... j1_Py
#    ... j1_Pz
#    ... j1_btag
#    ... j1_btagged
#    ... j1_eta
#    ... j1_idx
#    ... j1_mass
#    ... j1_phi
#    ... j1_pt
#    ... j2_E
#    ... j2_Px
#    ... j2_Py
#    ... j2_Pz
#    ... j2_btag
#    ... j2_btagged
#    ... j2_eta
#    ... j2_idx
#    ... j2_mass
#    ... j2_phi
#    ... j2_pt
#    ... j3_E
#    ... j3_Px
#    ... j3_Py
#    ... j3_Pz
#    ... j3_btag
#    ... j3_btagged
#    ... j3_eta
#    ... j3_idx
#    ... j3_mass
#    ... j3_phi
#    ... j3_pt
#    ... j4_E
#    ... j4_Px
#    ... j4_Py
#    ... j4_Pz
#    ... j4_btag
#    ... j4_btagged
#    ... j4_eta
#    ... j4_idx
#    ... j4_mass
#    ... j4_phi
#    ... j4_pt
#    ... j5_E
#    ... j5_Px
#    ... j5_Py
#    ... j5_Pz
#    ... j5_btag
#    ... j5_btagged
#    ... j5_eta
#    ... j5_idx
#    ... j5_mass
#    ... j5_phi
#    ... j5_pt
#    ... j6_E
#    ... j6_Px
#    ... j6_Py
#    ... j6_Pz
#    ... j6_btag
#    ... j6_btagged
#    ... j6_eta
#    ... j6_idx
#    ... j6_mass
#    ... j6_phi
#    ... j6_pt
#    ... j7_E
#    ... j7_Px
#    ... j7_Py
#    ... j7_Pz
#    ... j7_btag
#    ... j7_btagged
#    ... j7_eta
#    ... j7_idx
#    ... j7_mass
#    ... j7_phi
#    ... j7_pt
#    ... j8_E
#    ... j8_Px
#    ... j8_Py
#    ... j8_Pz
#    ... j8_btag
#    ... j8_btagged
#    ... j8_eta
#    ... j8_idx
#    ... j8_mass
#    ... j8_phi
#    ... j8_pt
#    ... j9_E
#    ... j9_Px
#    ... j9_Py
#    ... j9_Pz
#    ... j9_btag
#    ... j9_btagged
#    ... j9_eta
#    ... j9_idx
#    ... j9_mass
#    ... j9_phi
#    ... j9_pt
#    ... m1_E
#    ... m1_Px
#    ... m1_Py
#    ... m1_Pz
#    ... m1_charge
#    ... m1_eta
#    ... m1_idx
#    ... m1_mass
#    ... m1_pdgId
#    ... m1_phi
#    ... m1_pt
#    ... m2_E
#    ... m2_Px
#    ... m2_Py
#    ... m2_Pz
#    ... m2_charge
#    ... m2_eta
#    ... m2_idx
#    ... m2_mass
#    ... m2_pdgId
#    ... m2_phi
#    ... m2_pt
#    ... m3_E
#    ... m3_Px
#    ... m3_Py
#    ... m3_Pz
#    ... m3_charge
#    ... m3_eta
#    ... m3_idx
#    ... m3_mass
#    ... m3_pdgId
#    ... m3_phi
#    ... m3_pt
#    ... m4_E
#    ... m4_Px
#    ... m4_Py
#    ... m4_Pz
#    ... m4_charge
#    ... m4_eta
#    ... m4_idx
#    ... m4_mass
#    ... m4_pdgId
#    ... m4_phi
#    ... m4_pt
#    ... met_E
#    ... met_Px
#    ... met_Py
#    ... met_Pz
#    ... met_eta
#    ... met_mass
#    ... met_phi
#    ... met_pt
#    ... n_AK4B
#    ... n_AK8
#    ... n_AK8B
#    ... n_VBF
#    ... n_e
#    ... n_m

# %%
dataset = MultiplicityDataset(
    gen_dataset = gen_dataset,
    reco_data = reco_data,
    intersection_branch = 'event',
    use_weights = True,
)
targets = torch.where(dataset.targets)[1]
weights = dataset.weights

fix,axs = plt.subplots(ncols=3,nrows=1,figsize=(15,4))
axs[0].hist(targets,bins=torch.arange(0,10,1),histtype='step',color='b',label='Original')
axs[0].hist(targets,weights=weights,bins=torch.arange(0,10,1),histtype='step',color='r',label='Weighted')
axs[0].set_xlabel('Multiplicity')
axs[0].set_yscale('log')
axs[0].legend()


axs[1].hist(targets,bins=torch.arange(0,10,1),histtype='step',color='b',label='Original')
axs[1].hist(targets,weights=weights,bins=torch.arange(0,10,1),histtype='step',color='r',label='Weighted')
axs[1].set_xlabel('Multiplicity')
axs[1].legend()


h = axs[2].hist2d(
    targets,
    weights,
    bins = (
        torch.arange(0,dataset.targets.shape[1]+1,1),
        torch.logspace(torch.log10(weights.min()),torch.log10(weights.max()),101,)
    ),
    norm = matplotlib.colors.LogNorm(),
)
plt.colorbar(h[3],ax=axs[2])
axs[2].set_xlabel('Multiplicity')
axs[2].set_ylabel('Weight')
axs[2].set_yscale('log')


plt.show()
# Out:
# Looking into file metadata
# 	entry 0 : ['/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH0.root'
#  '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH1.root'
#  '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH2p45.root'
#  '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH5.root']
# 	entry 1 : ['/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH0.root'
#  '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH1.root'
#  '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH2p45.root'
#  '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH5.root']
# Will only consider common files : ['/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH0.root', '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH1.root', '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH2p45.root', '/home/ucl/cp3/fbury/scratch/MEM_data/Transfermer_v3/results/GluGluToHHTo2B2VTo2L2Nu_node_cHHH5.root']
# (Note : this assumes the files have the same order between the different data objects
# For entry 0 : from 1519507 events, 208466 selected
# For entry 1 : from 221454 events, 208466 selected
# tensor([0.0000e+00, 1.0000e+00, 3.2000e+01, 2.4300e+02, 1.0240e+03, 3.1250e+03,
#         7.7760e+03, 1.6807e+04, 3.2768e+04])

# %%
train_frac = 0.8
indices = torch.arange(len(dataset))
sep = int(train_frac*len(dataset))
train_indices = indices[:sep]
valid_indices = indices[sep:]

dataset_train = torch.utils.data.Subset(dataset,train_indices)
dataset_valid = torch.utils.data.Subset(dataset,valid_indices)
print (len(dataset_train),len(dataset_valid))

batch_size = 1024

loader_train = DataLoader(
    dataset_train,
    batch_size = batch_size,
    shuffle = True,
)
loader_valid = DataLoader(
    dataset_valid,
    batch_size = 10000,
    shuffle = False,
)
# Out:
# 166772 41694

# %%
model = MultiClassifier(
    number_objects = dataset.number_objects,
    dim_features = dataset.dim_features,
    n_max = dataset.max_length,
    neurons = [256]*6,
    hidden_activation = nn.ReLU,
    batch_norm = True,
    dropout = 0.,
)
print (model)

batch = next(iter(loader_train))
print (len(batch))
model.shared_eval(batch,0,'test')
# Out:
# MultiClassifier(
#   (hidden_layers): Sequential(
#     (0): Linear(in_features=24, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=256, out_features=256, bias=True)
#     (4): ReLU()
#     (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Linear(in_features=256, out_features=256, bias=True)
#     (7): ReLU()
#     (8): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): Linear(in_features=256, out_features=256, bias=True)
#     (10): ReLU()
#     (11): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): Linear(in_features=256, out_features=256, bias=True)
#     (13): ReLU()
#     (14): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): Linear(in_features=256, out_features=256, bias=True)
#     (16): ReLU()
#     (17): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (output_layer): Sequential(
#     (0): Linear(in_features=256, out_features=9, bias=True)
#     (1): Softmax(dim=1)
#   )
#   (loss_function): CrossEntropyLoss()
# )
# 3
# /home/ucl/cp3/fbury/scratch/anaconda3/envs/mem-flow/lib/python3.10/site-packages/lightning/pytorch/core/module.py:447: You are trying to `self.log()` but the `self.trainer` reference is not registered on the model yet. This is most likely because the model hasn't been passed to the `Trainer`
# tensor(2.2970, grad_fn=<MeanBackward0>)

# %%
model = model.cuda()
multiplicity = MultiplicityCallback(
    dataset = dataset,
    frequency = 5,
    raw = True,
    bins = 51,
    batch_size=10000,
    log_scale = True,
)

figs = multiplicity.make_plots(model=model,show=True)
# Out:
# Predict: 100%|██████████████████████████████████| 21/21 [00:02<00:00,  7.81it/s]

# %%
##### Parameters #####
epochs = 20
steps_per_epoch_train = math.ceil(len(dataset_train)/loader_train.batch_size)

print (f'Training   : Batch size = {loader_train.batch_size} => {steps_per_epoch_train} steps per epoch')
##### Optimizer #####
optimizer = optim.RAdam(model.parameters(), lr=1e-4)
model.set_optimizer(optimizer)

##### Scheduler #####
# scheduler = torch.optim.lr_scheduler.OneCycleLR(
#     optimizer = optimizer, 
#     max_lr = 1e-3, 
#     epochs = epochs, 
#     steps_per_epoch = steps_per_epoch_train, 
#     pct_start = 0.20, 
#     anneal_strategy='cos', 
#     cycle_momentum=True, 
#     base_momentum=0.85, 
#     max_momentum=0.95, 
#     div_factor=1e1, 
#     final_div_factor=1e3,
# )
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer = optimizer,
    mode='min', 
    factor=0.1, 
    patience=10, 
    threshold=0.001, 
    threshold_mode='rel', 
    cooldown=5, 
    min_lr=1e-7
)
model.set_scheduler_config(
    {
        'scheduler' : scheduler,
        'interval' : 'step' if isinstance(scheduler,optim.lr_scheduler.OneCycleLR) else 'epoch',
        'frequency' : 1,
        'monitor' : 'val/loss_tot',
        'strict' : True,
        'name' : 'scheduler',
    }
)

##### Callbacks #####
callbacks = [
    L.pytorch.callbacks.LearningRateMonitor(logging_interval='epoch'),
    L.pytorch.callbacks.ModelSummary(max_depth=2),
    #acceptance,
] 

##### Logger #####
logger = pl_loggers.CometLogger(
    save_dir = '../comet_logs',
    project_name = 'mem-flow-HH',
    experiment_name = 'Multiplicity',
    offline = False,
) 
logger.log_graph(model)
# logger.log_hyperparams()
# logger.experiment.log_code(folder='../src/')
logger.experiment.log_notebook(filename=globals()['__session__'],overwrite=True)

##### Trainer #####
trainer = L.Trainer(    
    min_epochs = 5,
    max_epochs = epochs,
    callbacks = callbacks,
    devices = 'auto',
    accelerator = accelerator,
    logger = logger,
    log_every_n_steps = steps_per_epoch_train,
)
##### Fit #####
trainer.fit(
    model = model, 
    train_dataloaders = loader_train,
    val_dataloaders = loader_valid,
)
# Out:
# CometLogger will be initialized in online mode
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# Training   : Batch size = 1024 => 163 steps per epoch
# COMET INFO: Experiment is live on comet.com https://www.comet.com/florianbury/mem-flow-hh/d326ac6eef9a45b49823318b1bdd442e
#
# /home/ucl/cp3/fbury/scratch/anaconda3/envs/mem-flow/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/ucl/cp3/fbury/scratch/anaconda3/envs/mem-flow/ ...
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name             | Type             | Params | Mode
# ---------------------------------------------------------------
# 0  | hidden_layers    | Sequential       | 338 K  | train
# 1  | hidden_layers.0  | Linear           | 6.4 K  | train
# 2  | hidden_layers.1  | ReLU             | 0      | train
# 3  | hidden_layers.2  | BatchNorm1d      | 512    | train
# 4  | hidden_layers.3  | Linear           | 65.8 K | train
# 5  | hidden_layers.4  | ReLU             | 0      | train
# 6  | hidden_layers.5  | BatchNorm1d      | 512    | train
# 7  | hidden_layers.6  | Linear           | 65.8 K | train
# 8  | hidden_layers.7  | ReLU             | 0      | train
# 9  | hidden_layers.8  | BatchNorm1d      | 512    | train
# 10 | hidden_layers.9  | Linear           | 65.8 K | train
# 11 | hidden_layers.10 | ReLU             | 0      | train
# 12 | hidden_layers.11 | BatchNorm1d      | 512    | train
# 13 | hidden_layers.12 | Linear           | 65.8 K | train
# 14 | hidden_layers.13 | ReLU             | 0      | train
# 15 | hidden_layers.14 | BatchNorm1d      | 512    | train
# 16 | hidden_layers.15 | Linear           | 65.8 K | train
# 17 | hidden_layers.16 | ReLU             | 0      | train
# 18 | hidden_layers.17 | BatchNorm1d      | 512    | train
# 19 | output_layer     | Sequential       | 2.3 K  | train
# 20 | output_layer.0   | Linear           | 2.3 K  | train
# 21 | output_layer.1   | Softmax          | 0      | train
# 22 | loss_function    | CrossEntropyLoss | 0      | train
# ---------------------------------------------------------------
# 340 K     Trainable params
# 0         Non-trainable params
# 340 K     Total params
# 1.363     Total estimated model params size (MB)
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=20` reached.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : Multiplicity
# COMET INFO:     url                   : https://www.comet.com/florianbury/mem-flow-hh/d326ac6eef9a45b49823318b1bdd442e
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     scheduler           : 0.0001
# COMET INFO:     train/loss_tot [20] : (1.583884835243225, 2.201082944869995)
# COMET INFO:     val/loss_tot [20]   : (2.140404224395752, 2.221099615097046)
# COMET INFO:   Others:
# COMET INFO:     Created from : pytorch-lightning
# COMET INFO:     Name         : Multiplicity
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (14.69 MB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     model graph                  : 1
# COMET INFO:     notebook                     : 2 (1.71 MB)
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.

# %%
figs = multiplicity.make_plots(model=model,show=True)
# Out:
# Predict: 100%|██████████████████████████████████| 21/21 [00:03<00:00,  5.87it/s]
